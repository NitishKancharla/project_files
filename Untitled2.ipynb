# %%
# !pip install speechrecognition pyttsx3 google-generativeai requests pdfplumber python-docx
# Out:
# Requirement already satisfied: speechrecognition in /Users/nitish/opt/anaconda3/envs/llms/lib/python3.11/site-packages (3.14.2)
# Collecting pyttsx3
#   Using cached pyttsx3-2.98-py3-none-any.whl.metadata (3.8 kB)
# Requirement already satisfied: google-generativeai in /Users/nitish/opt/anaconda3/envs/llms/lib/python3.11/site-packages (0.8.4)
# Requirement already satisfied: requests in /Users/nitish/opt/anaconda3/envs/llms/lib/python3.11/site-packages (2.32.3)
# Requirement already satisfied: pdfplumber in /Users/nitish/opt/anaconda3/envs/llms/lib/python3.11/site-packages (0.11.5)
# Requirement already satisfied: python-docx in /Users/nitish/opt/anaconda3/envs/llms/lib/python3.11/site-packages (1.1.2)
# Requirement already satisfied: typing-extensions in /Users/nitish/opt/anaconda3/envs/llms/lib/python3.11/site-packages (from speechrecognition) (4.12.2)
# Collecting pyobjc>=2.4 (from pyttsx3)
#   Using cached pyobjc-11.0-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: google-ai-generativelanguage==0.6.15 in /Users/nitish/opt/anaconda3/envs/llms/lib/python3.11/site-packages (from google-generativeai) (0.6.15)
# Requirement already satisfied: google-api-core in /Users/nitish/opt/anaconda3/envs/llms/lib/python3.11/site-packages (from google-generativeai) (2.24.2)
# Requirement already satisfied: google-api-python-client in /Users/nitish/opt/anaconda3/envs/llms/lib/python3.11/site-packages (from google-generativeai) (2.165.0)
# Requirement already satisfied: google-auth>=2.15.0 in /Users/nitish/opt/anaconda3/envs/llms/lib/python3.11/site-packages (from google-generativeai) (2.38.0)
# Requirement already satisfied: protobuf in /Users/nitish/opt/anaconda3/envs/llms/lib/python3.11/site-packages (from google-generativeai) (5.29.3)
# Requirement already satisfied: pydantic in /Users/nitish/opt/anaconda3/envs/llms/lib/python3.11/site-packages (from google-generativeai) (2.10.6)
# Requirement already satisfied: tqdm in /Users/nitish/opt/anaconda3/envs/llms/lib/python3.11/site-packages (from google-generativeai) (4.67.1)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in /Users/nitish/opt/anaconda3/envs/llms/lib/python3.11/site-packages (from google-ai-generativelanguage==0.6.15->google-generativeai) (1.26.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/nitish/opt/anaconda3/envs/llms/lib/python3.11/site-packages (from requests) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /Users/nitish/opt/anaconda3/envs/llms/lib/python3.11/site-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/nitish/opt/anaconda3/envs/llms/lib/python3.11/site-packages (from requests) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/nitish/opt/anaconda3/envs/llms/lib/python3.11/site-packages (from requests) (2025.1.31)
# Requirement already satisfied: pdfminer.six==20231228 in /Users/nitish/opt/anaconda3/envs/llms/lib/python3.11/site-packages (from pdfplumber) (20231228)
# Requirement already satisfied: Pillow>=9.1 in /Users/nitish/opt/anaconda3/envs/llms/lib/python3.11/site-packages (from pdfplumber) (11.1.0)
# Requirement already satisfied: pypdfium2>=4.18.0 in /Users/nitish/opt/anaconda3/envs/llms/lib/python3.11/site-packages (from pdfplumber) (4.30.1)
# Requirement already satisfied: cryptography>=36.0.0 in /Users/nitish/opt/anaconda3/envs/llms/lib/python3.11/site-packages (from pdfminer.six==20231228->pdfplumber) (44.0.2)
# Requirement already satisfied: lxml>=3.1.0 in /Users/nitish/opt/anaconda3/envs/llms/lib/python3.11/site-packages (from python-docx) (5.3.1)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in /Users/nitish/opt/anaconda3/envs/llms/lib/python3.11/site-packages (from google-api-core->google-generativeai) (1.69.2)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Users/nitish/opt/anaconda3/envs/llms/lib/python3.11/site-packages (from google-auth>=2.15.0->google-generativeai) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/nitish/opt/anaconda3/envs/llms/lib/python3.11/site-packages (from google-auth>=2.15.0->google-generativeai) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/nitish/opt/anaconda3/envs/llms/lib/python3.11/site-packages (from google-auth>=2.15.0->google-generativeai) (4.9)
# Requirement already satisfied: pyobjc-core==11.0 in /Users/nitish/opt/anaconda3/envs/llms/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Collecting pyobjc-framework-libdispatch==11.0 (from pyobjc>=2.4->pyttsx3)
#   Using cached pyobjc_framework_libdispatch-11.0-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.2 kB)
# Collecting pyobjc-framework-libxpc==11.0 (from pyobjc>=2.4->pyttsx3)
#   Using cached pyobjc_framework_libxpc-11.0-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.2 kB)
# Collecting pyobjc-framework-Accessibility==11.0 (from pyobjc>=2.4->pyttsx3)
#   Using cached pyobjc_framework_Accessibility-11.0-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.3 kB)
# Collecting pyobjc-framework-AdServices==11.0 (from pyobjc>=2.4->pyttsx3)
#   Using cached pyobjc_framework_AdServices-11.0-py3-none-any.whl.metadata (2.5 kB)
# Collecting pyobjc-framework-AdSupport==11.0 (from pyobjc>=2.4->pyttsx3)
#   Using cached pyobjc_framework_AdSupport-11.0-py3-none-any.whl.metadata (2.5 kB)
# Collecting pyobjc-framework-AppTrackingTransparency==11.0 (from pyobjc>=2.4->pyttsx3)
#   Using cached pyobjc_framework_AppTrackingTransparency-11.0-py3-none-any.whl.metadata (2.5 kB)
# Collecting pyobjc-framework-AudioVideoBridging==11.0 (from pyobjc>=2.4->pyttsx3)
#   Using cached pyobjc_framework_AudioVideoBridging-11.0-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.3 kB)
# Collecting pyobjc-framework-AuthenticationServices==11.0 (from pyobjc>=2.4->pyttsx3)
#   Using cached pyobjc_framework_AuthenticationServices-11.0-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.3 kB)
# Collecting pyobjc-framework-AutomaticAssessmentConfiguration==11.0 (from pyobjc>=2.4->pyttsx3)
#   Using cached pyobjc_framework_AutomaticAssessmentConfiguration-11.0-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.3 kB)
# Collecting pyobjc-framework-AVKit==11.0 (from pyobjc>=2.4->pyttsx3)
#   Using cached pyobjc_framework_AVKit-11.0-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.3 kB)
# Collecting pyobjc-framework-AVFoundation==11.0 (from pyobjc>=2.4->pyttsx3)
#   Using cached pyobjc_framework_AVFoundation-11.0-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.4 kB)
# Collecting pyobjc-framework-AVRouting==11.0 (from pyobjc>=2.4->pyttsx3)
#   Using cached pyobjc_framework_AVRouting-11.0-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.2 kB)
# Collecting pyobjc-framework-Accounts==11.0 (from pyobjc>=2.4->pyttsx3)
#   Using cached pyobjc_framework_Accounts-11.0-py3-none-any.whl.metadata (2.5 kB)
# Collecting pyobjc-framework-AddressBook==11.0 (from pyobjc>=2.4->pyttsx3)
#   Using cached pyobjc_framework_AddressBook-11.0-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.4 kB)
# Collecting pyobjc-framework-AppleScriptKit==11.0 (from pyobjc>=2.4->pyttsx3)
#   Using cached pyobjc_framework_AppleScriptKit-11.0-py3-none-any.whl.metadata (2.5 kB)
# Collecting pyobjc-framework-AppleScriptObjC==11.0 (from pyobjc>=2.4->pyttsx3)
#   Using cached pyobjc_framework_AppleScriptObjC-11.0-py3-none-any.whl.metadata (2.7 kB)
# Collecting pyobjc-framework-ApplicationServices==11.0 (from pyobjc>=2.4->pyttsx3)
#   Using cached pyobjc_framework_ApplicationServices-11.0-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.5 kB)
# Collecting pyobjc-framework-Automator==11.0 (from pyobjc>=2.4->pyttsx3)
#   Using cached pyobjc_framework_Automator-11.0-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.5 kB)
# Collecting pyobjc-framework-BackgroundAssets==11.0 (from pyobjc>=2.4->pyttsx3)
#   Using cached pyobjc_framework_BackgroundAssets-11.0-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.3 kB)
# Collecting pyobjc-framework-BrowserEngineKit==11.0 (from pyobjc>=2.4->pyttsx3)
#   Using cached pyobjc_framework_BrowserEngineKit-11.0-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.4 kB)
# Collecting pyobjc-framework-BusinessChat==11.0 (from pyobjc>=2.4->pyttsx3)
#   Using cached pyobjc_framework_BusinessChat-11.0-py3-none-any.whl.metadata (2.5 kB)
# Collecting pyobjc-framework-CFNetwork==11.0 (from pyobjc>=2.4->pyttsx3)
#   Using cached pyobjc_framework_CFNetwork-11.0-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.5 kB)
# Collecting pyobjc-framework-CalendarStore==11.0 (from pyobjc>=2.4->pyttsx3)
#   Using cached pyobjc_framework_CalendarStore-11.0-py3-none-any.whl.metadata (2.7 kB)
# Collecting pyobjc-framework-CallKit==11.0 (from pyobjc>=2.4->pyttsx3)
#   Using cached pyobjc_framework_CallKit-11.0-py3-none-any.whl.metadata (2.5 kB)
# Collecting pyobjc-framework-Carbon==11.0 (from pyobjc>=2.4->pyttsx3)
#   Using cached pyobjc_framework_Carbon-11.0-py3-none-any.whl.metadata (2.5 kB)
# Collecting pyobjc-framework-Cinematic==11.0 (from pyobjc>=2.4->pyttsx3)
#   Using cached pyobjc_framework_Cinematic-11.0-py3-none-any.whl.metadata (2.6 kB)
# Collecting pyobjc-framework-ClassKit==11.0 (from pyobjc>=2.4->pyttsx3)
#   Using cached pyobjc_framework_ClassKit-11.0-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.2 kB)
# Collecting pyobjc-framework-CloudKit==11.0 (from pyobjc>=2.4->pyttsx3)
#   Using cached pyobjc_framework_CloudKit-11.0-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: pyobjc-framework-Cocoa==11.0 in /Users/nitish/opt/anaconda3/envs/llms/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (11.0)
# Collecting pyobjc-framework-Collaboration==11.0 (from pyobjc>=2.4->pyttsx3)
#   Using cached pyobjc_framework_Collaboration-11.0-py3-none-any.whl.metadata (2.7 kB)
# Collecting pyobjc-framework-ColorSync==11.0 (from pyobjc>=2.4->pyttsx3)
#   Using cached pyobjc_framework_ColorSync-11.0-py3-none-any.whl.metadata (2.5 kB)
# Collecting pyobjc-framework-Contacts==11.0 (from pyobjc>=2.4->pyttsx3)
#   Using cached pyobjc_framework_Contacts-11.0-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.2 kB)
# Collecting pyobjc-framework-ContactsUI==11.0 (from pyobjc>=2.4->pyttsx3)
#   Using cached pyobjc_framework_ContactsUI-11.0-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.3 kB)
# Collecting pyobjc-framework-CoreAudio==11.0 (from pyobjc>=2.4->pyttsx3)
#   Using cached pyobjc_framework_CoreAudio-11.0-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.2 kB)
# Collecting pyobjc-framework-CoreAudioKit==11.0 (from pyobjc>=2.4->pyttsx3)
#   Using cached pyobjc_framework_CoreAudioKit-11.0-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.3 kB)
# Collecting pyobjc-framework-CoreBluetooth==11.0 (from pyobjc>=2.4->pyttsx3)
#   Using cached pyobjc_framework_CoreBluetooth-11.0-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.3 kB)
# Collecting pyobjc-framework-CoreData==11.0 (from pyobjc>=2.4->pyttsx3)
#   Using cached pyobjc_framework_CoreData-11.0-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.4 kB)
# Collecting pyobjc-framework-CoreHaptics==11.0 (from pyobjc>=2.4->pyttsx3)
#   Using cached pyobjc_framework_CoreHaptics-11.0-py3-none-any.whl.metadata (2.5 kB)
# Collecting pyobjc-framework-CoreLocation==11.0 (from pyobjc>=2.4->pyttsx3)
#   Using cached pyobjc_framework_CoreLocation-11.0-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.4 kB)
# Collecting pyobjc-framework-CoreMedia==11.0 (from pyobjc>=2.4->pyttsx3)
#   Using cached pyobjc_framework_CoreMedia-11.0-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.2 kB)
# Collecting pyobjc-framework-CoreMediaIO==11.0 (from pyobjc>=2.4->pyttsx3)
#   Using cached pyobjc_framework_CoreMediaIO-11.0-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.2 kB)
# Collecting pyobjc-framework-CoreMIDI==11.0 (from pyobjc>=2.4->pyttsx3)
#   Using cached pyobjc_framework_CoreMIDI-11.0-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.2 kB)
# Collecting pyobjc-framework-CoreML==11.0 (from pyobjc>=2.4->pyttsx3)
#   Using cached pyobjc_framework_CoreML-11.0-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.2 kB)
# Collecting pyobjc-framework-CoreMotion==11.0 (from pyobjc>=2.4->pyttsx3)
#   Using cached pyobjc_framework_CoreMotion-11.0-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.2 kB)
# Collecting pyobjc-framework-CoreServices==11.0 (from pyobjc>=2.4->pyttsx3)
#   Using cached pyobjc_framework_CoreServices-11.0-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.4 kB)
# Collecting pyobjc-framework-CoreSpotlight==11.0 (from pyobjc>=2.4->pyttsx3)
#   Using cached pyobjc_framework_CoreSpotlight-11.0-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.3 kB)
# Collecting pyobjc-framework-CoreText==11.0 (from pyobjc>=2.4->pyttsx3)
#   Using cached pyobjc_framework_CoreText-11.0-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.5 kB)
# Collecting pyobjc-framework-CoreWLAN==11.0 (from pyobjc>=2.4->pyttsx3)
#   Using cached pyobjc_framework_CoreWLAN-11.0-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.2 kB)
# Collecting pyobjc-framework-CryptoTokenKit==11.0 (from pyobjc>=2.4->pyttsx3)
#   Using cached pyobjc_framework_CryptoTokenKit-11.0-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.3 kB)
# Collecting pyobjc-framework-DataDetection==11.0 (from pyobjc>=2.4->pyttsx3)
#   Using cached pyobjc_framework_DataDetection-11.0-py3-none-any.whl.metadata (2.5 kB)
# Collecting pyobjc-framework-DeviceCheck==11.0 (from pyobjc>=2.4->pyttsx3)
#   Using cached pyobjc_framework_DeviceCheck-11.0-py3-none-any.whl.metadata (2.5 kB)
# Collecting pyobjc-framework-DeviceDiscoveryExtension==11.0 (from pyobjc>=2.4->pyttsx3)
#   Using cached pyobjc_framework_DeviceDiscoveryExtension-11.0-py3-none-any.whl.metadata (2.5 kB)
# Collecting pyobjc-framework-DictionaryServices==11.0 (from pyobjc>=2.4->pyttsx3)
#   Using cached pyobjc_framework_DictionaryServices-11.0-py3-none-any.whl.metadata (2.4 kB)
# Collecting pyobjc-framework-DiscRecording==11.0 (from pyobjc>=2.4->pyttsx3)
#   Using cached pyobjc_framework_DiscRecording-11.0-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.2 kB)
# Collecting pyobjc-framework-DiscRecordingUI==11.0 (from pyobjc>=2.4->pyttsx3)
#   Using cached pyobjc_framework_DiscRecordingUI-11.0-py3-none-any.whl.metadata (2.6 kB)
# Collecting pyobjc-framework-DiskArbitration==11.0 (from pyobjc>=2.4->pyttsx3)
#   Using cached pyobjc_framework_DiskArbitration-11.0-py3-none-any.whl.metadata (2.5 kB)
# Collecting pyobjc-framework-DVDPlayback==11.0 (from pyobjc>=2.4->pyttsx3)
#   Using cached pyobjc_framework_DVDPlayback-11.0-py3-none-any.whl.metadata (2.5 kB)
# Collecting pyobjc-framework-EventKit==11.0 (from pyobjc>=2.4->pyttsx3)
#   Using cached pyobjc_framework_EventKit-11.0-py3-none-any.whl.metadata (2.5 kB)
# Collecting pyobjc-framework-ExceptionHandling==11.0 (from pyobjc>=2.4->pyttsx3)
#   Using cached pyobjc_framework_ExceptionHandling-11.0-py3-none-any.whl.metadata (2.8 kB)
# Collecting pyobjc-framework-ExecutionPolicy==11.0 (from pyobjc>=2.4->pyttsx3)
#   Using cached pyobjc_framework_ExecutionPolicy-11.0-py3-none-any.whl.metadata (2.5 kB)
# Collecting pyobjc-framework-ExternalAccessory==11.0 (from pyobjc>=2.4->pyttsx3)
#   Using cached pyobjc_framework_ExternalAccessory-11.0-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.3 kB)
# Collecting pyobjc-framework-ExtensionKit==11.0 (from pyobjc>=2.4->pyttsx3)
#   Using cached pyobjc_framework_ExtensionKit-11.0-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.3 kB)
# Collecting pyobjc-framework-FileProvider==11.0 (from pyobjc>=2.4->pyttsx3)
#   Using cached pyobjc_framework_FileProvider-11.0-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.3 kB)
# Collecting pyobjc-framework-FileProviderUI==11.0 (from pyobjc>=2.4->pyttsx3)
#   Using cached pyobjc_framework_FileProviderUI-11.0-py3-none-any.whl.metadata (2.5 kB)
# Collecting pyobjc-framework-FSEvents==11.0 (from pyobjc>=2.4->pyttsx3)
#   Using cached pyobjc_framework_FSEvents-11.0-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.4 kB)
# Collecting pyobjc-framework-FinderSync==11.0 (from pyobjc>=2.4->pyttsx3)
#   Using cached pyobjc_framework_FinderSync-11.0-py3-none-any.whl.metadata (2.5 kB)
# Collecting pyobjc-framework-GameCenter==11.0 (from pyobjc>=2.4->pyttsx3)
#   Using cached pyobjc_framework_GameCenter-11.0-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.2 kB)
# Collecting pyobjc-framework-GameController==11.0 (from pyobjc>=2.4->pyttsx3)
#   Using cached pyobjc_framework_GameController-11.0-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.3 kB)
# Collecting pyobjc-framework-HealthKit==11.0 (from pyobjc>=2.4->pyttsx3)
#   Using cached pyobjc_framework_HealthKit-11.0-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.2 kB)
# Collecting pyobjc-framework-InputMethodKit==11.0 (from pyobjc>=2.4->pyttsx3)
#   Using cached pyobjc_framework_InputMethodKit-11.0-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.4 kB)
# Collecting pyobjc-framework-ImageCaptureCore==11.0 (from pyobjc>=2.4->pyttsx3)
#   Using cached pyobjc_framework_ImageCaptureCore-11.0-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.3 kB)
# Collecting pyobjc-framework-Intents==11.0 (from pyobjc>=2.4->pyttsx3)
#   Using cached pyobjc_framework_Intents-11.0-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.2 kB)
# Collecting pyobjc-framework-IntentsUI==11.0 (from pyobjc>=2.4->pyttsx3)
#   Using cached pyobjc_framework_IntentsUI-11.0-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.2 kB)
# Collecting pyobjc-framework-InstallerPlugins==11.0 (from pyobjc>=2.4->pyttsx3)
#   Using cached pyobjc_framework_InstallerPlugins-11.0-py3-none-any.whl.metadata (2.7 kB)
# Collecting pyobjc-framework-InstantMessage==11.0 (from pyobjc>=2.4->pyttsx3)
#   Using cached pyobjc_framework_InstantMessage-11.0-py3-none-any.whl.metadata (2.8 kB)
# Collecting pyobjc-framework-IOBluetooth==11.0 (from pyobjc>=2.4->pyttsx3)
#   Using cached pyobjc_framework_IOBluetooth-11.0-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.2 kB)
# Collecting pyobjc-framework-IOBluetoothUI==11.0 (from pyobjc>=2.4->pyttsx3)
#   Using cached pyobjc_framework_IOBluetoothUI-11.0-py3-none-any.whl.metadata (2.5 kB)
# Collecting pyobjc-framework-IOSurface==11.0 (from pyobjc>=2.4->pyttsx3)
#   Using cached pyobjc_framework_IOSurface-11.0-py3-none-any.whl.metadata (2.5 kB)
# Collecting pyobjc-framework-KernelManagement==11.0 (from pyobjc>=2.4->pyttsx3)
#   Using cached pyobjc_framework_KernelManagement-11.0-py3-none-any.whl.metadata (2.5 kB)
# Collecting pyobjc-framework-LatentSemanticMapping==11.0 (from pyobjc>=2.4->pyttsx3)
#   Using cached pyobjc_framework_LatentSemanticMapping-11.0-py3-none-any.whl.metadata (2.8 kB)
# Collecting pyobjc-framework-LaunchServices==11.0 (from pyobjc>=2.4->pyttsx3)
#   Using cached pyobjc_framework_LaunchServices-11.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting pyobjc-framework-LinkPresentation==11.0 (from pyobjc>=2.4->pyttsx3)
#   Using cached pyobjc_framework_LinkPresentation-11.0-py3-none-any.whl.metadata (2.6 kB)
# Collecting pyobjc-framework-LocalAuthentication==11.0 (from pyobjc>=2.4->pyttsx3)
#   Using cached pyobjc_framework_LocalAuthentication-11.0-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.4 kB)
# Collecting pyobjc-framework-LocalAuthenticationEmbeddedUI==11.0 (from pyobjc>=2.4->pyttsx3)
#   Using cached pyobjc_framework_LocalAuthenticationEmbeddedUI-11.0-py3-none-any.whl.metadata (2.6 kB)
# Collecting pyobjc-framework-MailKit==11.0 (from pyobjc>=2.4->pyttsx3)
#   Using cached pyobjc_framework_MailKit-11.0-py3-none-any.whl.metadata (2.5 kB)
# Collecting pyobjc-framework-MapKit==11.0 (from pyobjc>=2.4->pyttsx3)
#   Using cached pyobjc_framework_MapKit-11.0-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.4 kB)
# Collecting pyobjc-framework-MediaAccessibility==11.0 (from pyobjc>=2.4->pyttsx3)
#   Using cached pyobjc_framework_MediaAccessibility-11.0-py3-none-any.whl.metadata (2.5 kB)
# Collecting pyobjc-framework-MediaExtension==11.0 (from pyobjc>=2.4->pyttsx3)
#   Using cached pyobjc_framework_MediaExtension-11.0-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.4 kB)
# Collecting pyobjc-framework-MediaLibrary==11.0 (from pyobjc>=2.4->pyttsx3)
#   Using cached pyobjc_framework_MediaLibrary-11.0-py3-none-any.whl.metadata (2.6 kB)
# Collecting pyobjc-framework-MediaPlayer==11.0 (from pyobjc>=2.4->pyttsx3)
#   Using cached pyobjc_framework_MediaPlayer-11.0-py3-none-any.whl.metadata (2.5 kB)
# Collecting pyobjc-framework-MediaToolbox==11.0 (from pyobjc>=2.4->pyttsx3)
#   Using cached pyobjc_framework_MediaToolbox-11.0-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.3 kB)
# Collecting pyobjc-framework-Metal==11.0 (from pyobjc>=2.4->pyttsx3)
#   Using cached pyobjc_framework_Metal-11.0-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.2 kB)
# Collecting pyobjc-framework-MetalFX==11.0 (from pyobjc>=2.4->pyttsx3)
#   Using cached pyobjc_framework_MetalFX-11.0-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.2 kB)
# Collecting pyobjc-framework-MetalKit==11.0 (from pyobjc>=2.4->pyttsx3)
#   Using cached pyobjc_framework_MetalKit-11.0-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.3 kB)
# Collecting pyobjc-framework-MetalPerformanceShaders==11.0 (from pyobjc>=2.4->pyttsx3)
#   Using cached pyobjc_framework_MetalPerformanceShaders-11.0-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.3 kB)
# Collecting pyobjc-framework-MetalPerformanceShadersGraph==11.0 (from pyobjc>=2.4->pyttsx3)
#   Using cached pyobjc_framework_MetalPerformanceShadersGraph-11.0-py3-none-any.whl.metadata (2.6 kB)
# Collecting pyobjc-framework-MetricKit==11.0 (from pyobjc>=2.4->pyttsx3)
#   Using cached pyobjc_framework_MetricKit-11.0-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.2 kB)
# Collecting pyobjc-framework-MLCompute==11.0 (from pyobjc>=2.4->pyttsx3)
#   Using cached pyobjc_framework_MLCompute-11.0-py3-none-any.whl.metadata (2.5 kB)
# Collecting pyobjc-framework-ModelIO==11.0 (from pyobjc>=2.4->pyttsx3)
#   Using cached pyobjc_framework_ModelIO-11.0-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.3 kB)
# Collecting pyobjc-framework-MultipeerConnectivity==11.0 (from pyobjc>=2.4->pyttsx3)
#   Using cached pyobjc_framework_MultipeerConnectivity-11.0-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.3 kB)
# Collecting pyobjc-framework-NaturalLanguage==11.0 (from pyobjc>=2.4->pyttsx3)
#   Using cached pyobjc_framework_NaturalLanguage-11.0-py3-none-any.whl.metadata (2.5 kB)
# Collecting pyobjc-framework-NetFS==11.0 (from pyobjc>=2.4->pyttsx3)
#   Using cached pyobjc_framework_NetFS-11.0-py3-none-any.whl.metadata (2.5 kB)
# Collecting pyobjc-framework-Network==11.0 (from pyobjc>=2.4->pyttsx3)
#   Using cached pyobjc_framework_Network-11.0-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.2 kB)
# Collecting pyobjc-framework-NetworkExtension==11.0 (from pyobjc>=2.4->pyttsx3)
#   Using cached pyobjc_framework_NetworkExtension-11.0-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.3 kB)
# Collecting pyobjc-framework-NotificationCenter==11.0 (from pyobjc>=2.4->pyttsx3)
#   Using cached pyobjc_framework_NotificationCenter-11.0-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.3 kB)
# Collecting pyobjc-framework-OpenDirectory==11.0 (from pyobjc>=2.4->pyttsx3)
#   Using cached pyobjc_framework_OpenDirectory-11.0-py3-none-any.whl.metadata (2.6 kB)
# Collecting pyobjc-framework-OSAKit==11.0 (from pyobjc>=2.4->pyttsx3)
#   Using cached pyobjc_framework_OSAKit-11.0-py3-none-any.whl.metadata (2.5 kB)
# Collecting pyobjc-framework-OSLog==11.0 (from pyobjc>=2.4->pyttsx3)
#   Using cached pyobjc_framework_OSLog-11.0-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.3 kB)
# Collecting pyobjc-framework-PassKit==11.0 (from pyobjc>=2.4->pyttsx3)
#   Using cached pyobjc_framework_PassKit-11.0-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.2 kB)
# Collecting pyobjc-framework-PencilKit==11.0 (from pyobjc>=2.4->pyttsx3)
#   Using cached pyobjc_framework_PencilKit-11.0-py3-none-any.whl.metadata (2.5 kB)
# Collecting pyobjc-framework-PHASE==11.0 (from pyobjc>=2.4->pyttsx3)
#   Using cached pyobjc_framework_PHASE-11.0-py3-none-any.whl.metadata (2.5 kB)
# Collecting pyobjc-framework-Photos==11.0 (from pyobjc>=2.4->pyttsx3)
#   Using cached pyobjc_framework_Photos-11.0-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.2 kB)
# Collecting pyobjc-framework-PhotosUI==11.0 (from pyobjc>=2.4->pyttsx3)
#   Using cached pyobjc_framework_PhotosUI-11.0-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.2 kB)
# Collecting pyobjc-framework-PreferencePanes==11.0 (from pyobjc>=2.4->pyttsx3)
#   Using cached pyobjc_framework_PreferencePanes-11.0-py3-none-any.whl.metadata (2.6 kB)
# Collecting pyobjc-framework-PushKit==11.0 (from pyobjc>=2.4->pyttsx3)
#   Using cached pyobjc_framework_PushKit-11.0-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.3 kB)
# Collecting pyobjc-framework-Quartz==11.0 (from pyobjc>=2.4->pyttsx3)
#   Using cached pyobjc_framework_Quartz-11.0-cp311-cp311-macosx_10_9_universal2.whl.metadata (3.3 kB)
# Collecting pyobjc-framework-QuickLookThumbnailing==11.0 (from pyobjc>=2.4->pyttsx3)
#   Using cached pyobjc_framework_QuickLookThumbnailing-11.0-py3-none-any.whl.metadata (2.6 kB)
# Collecting pyobjc-framework-ReplayKit==11.0 (from pyobjc>=2.4->pyttsx3)
#   Using cached pyobjc_framework_ReplayKit-11.0-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.2 kB)
# Collecting pyobjc-framework-SafetyKit==11.0 (from pyobjc>=2.4->pyttsx3)
#   Using cached pyobjc_framework_SafetyKit-11.0-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.3 kB)
# Collecting pyobjc-framework-SafariServices==11.0 (from pyobjc>=2.4->pyttsx3)
#   Using cached pyobjc_framework_SafariServices-11.0-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.3 kB)
# Collecting pyobjc-framework-ScreenSaver==11.0 (from pyobjc>=2.4->pyttsx3)
#   Using cached pyobjc_framework_ScreenSaver-11.0-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.3 kB)
# Collecting pyobjc-framework-ScreenTime==11.0 (from pyobjc>=2.4->pyttsx3)
#   Using cached pyobjc_framework_ScreenTime-11.0-py3-none-any.whl.metadata (2.5 kB)
# Collecting pyobjc-framework-ScriptingBridge==11.0 (from pyobjc>=2.4->pyttsx3)
#   Using cached pyobjc_framework_ScriptingBridge-11.0-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.6 kB)
# Collecting pyobjc-framework-Security==11.0 (from pyobjc>=2.4->pyttsx3)
#   Using cached pyobjc_framework_Security-11.0-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.2 kB)
# Collecting pyobjc-framework-SecurityFoundation==11.0 (from pyobjc>=2.4->pyttsx3)
#   Using cached pyobjc_framework_SecurityFoundation-11.0-py3-none-any.whl.metadata (2.6 kB)
# Collecting pyobjc-framework-SecurityInterface==11.0 (from pyobjc>=2.4->pyttsx3)
#   Using cached pyobjc_framework_SecurityInterface-11.0-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.3 kB)
# Collecting pyobjc-framework-SearchKit==11.0 (from pyobjc>=2.4->pyttsx3)
#   Using cached pyobjc_framework_SearchKit-11.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting pyobjc-framework-ServiceManagement==11.0 (from pyobjc>=2.4->pyttsx3)
#   Using cached pyobjc_framework_ServiceManagement-11.0-py3-none-any.whl.metadata (2.7 kB)
# Collecting pyobjc-framework-ShazamKit==11.0 (from pyobjc>=2.4->pyttsx3)
#   Using cached pyobjc_framework_ShazamKit-11.0-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.2 kB)
# Collecting pyobjc-framework-Social==11.0 (from pyobjc>=2.4->pyttsx3)
#   Using cached pyobjc_framework_Social-11.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting pyobjc-framework-Speech==11.0 (from pyobjc>=2.4->pyttsx3)
#   Using cached pyobjc_framework_Speech-11.0-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.2 kB)
# Collecting pyobjc-framework-SpriteKit==11.0 (from pyobjc>=2.4->pyttsx3)
#   Using cached pyobjc_framework_SpriteKit-11.0-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.3 kB)
# Collecting pyobjc-framework-StoreKit==11.0 (from pyobjc>=2.4->pyttsx3)
#   Using cached pyobjc_framework_StoreKit-11.0-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.3 kB)
# Collecting pyobjc-framework-SyncServices==11.0 (from pyobjc>=2.4->pyttsx3)
#   Using cached pyobjc_framework_SyncServices-11.0-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.6 kB)
# Collecting pyobjc-framework-SystemConfiguration==11.0 (from pyobjc>=2.4->pyttsx3)
#   Using cached pyobjc_framework_SystemConfiguration-11.0-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.3 kB)
# Collecting pyobjc-framework-WebKit==11.0 (from pyobjc>=2.4->pyttsx3)
#   Using cached pyobjc_framework_WebKit-11.0-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.4 kB)
# Collecting pyobjc-framework-GameKit==11.0 (from pyobjc>=2.4->pyttsx3)
#   Using cached pyobjc_framework_GameKit-11.0-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.3 kB)
# Collecting pyobjc-framework-GameplayKit==11.0 (from pyobjc>=2.4->pyttsx3)
#   Using cached pyobjc_framework_GameplayKit-11.0-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.3 kB)
# Collecting pyobjc-framework-SceneKit==11.0 (from pyobjc>=2.4->pyttsx3)
#   Using cached pyobjc_framework_SceneKit-11.0-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.3 kB)
# Collecting pyobjc-framework-SensitiveContentAnalysis==11.0 (from pyobjc>=2.4->pyttsx3)
#   Using cached pyobjc_framework_SensitiveContentAnalysis-11.0-py3-none-any.whl.metadata (2.6 kB)
# Collecting pyobjc-framework-SharedWithYouCore==11.0 (from pyobjc>=2.4->pyttsx3)
#   Using cached pyobjc_framework_SharedWithYouCore-11.0-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.3 kB)
# Collecting pyobjc-framework-SharedWithYou==11.0 (from pyobjc>=2.4->pyttsx3)
#   Using cached pyobjc_framework_SharedWithYou-11.0-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.3 kB)
# Collecting pyobjc-framework-SoundAnalysis==11.0 (from pyobjc>=2.4->pyttsx3)
#   Using cached pyobjc_framework_SoundAnalysis-11.0-py3-none-any.whl.metadata (2.5 kB)
# Collecting pyobjc-framework-ScreenCaptureKit==11.0 (from pyobjc>=2.4->pyttsx3)
#   Using cached pyobjc_framework_ScreenCaptureKit-11.0-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.3 kB)
# Collecting pyobjc-framework-Symbols==11.0 (from pyobjc>=2.4->pyttsx3)
#   Using cached pyobjc_framework_Symbols-11.0-py3-none-any.whl.metadata (2.5 kB)
# Collecting pyobjc-framework-SystemExtensions==11.0 (from pyobjc>=2.4->pyttsx3)
#   Using cached pyobjc_framework_SystemExtensions-11.0-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.3 kB)
# Collecting pyobjc-framework-ThreadNetwork==11.0 (from pyobjc>=2.4->pyttsx3)
#   Using cached pyobjc_framework_ThreadNetwork-11.0-py3-none-any.whl.metadata (2.5 kB)
# Collecting pyobjc-framework-UniformTypeIdentifiers==11.0 (from pyobjc>=2.4->pyttsx3)
#   Using cached pyobjc_framework_UniformTypeIdentifiers-11.0-py3-none-any.whl.metadata (2.5 kB)
# Collecting pyobjc-framework-UserNotifications==11.0 (from pyobjc>=2.4->pyttsx3)
#   Using cached pyobjc_framework_UserNotifications-11.0-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.3 kB)
# Collecting pyobjc-framework-UserNotificationsUI==11.0 (from pyobjc>=2.4->pyttsx3)
#   Using cached pyobjc_framework_UserNotificationsUI-11.0-py3-none-any.whl.metadata (2.6 kB)
# Collecting pyobjc-framework-VideoSubscriberAccount==11.0 (from pyobjc>=2.4->pyttsx3)
#   Using cached pyobjc_framework_VideoSubscriberAccount-11.0-py3-none-any.whl.metadata (2.5 kB)
# Collecting pyobjc-framework-VideoToolbox==11.0 (from pyobjc>=2.4->pyttsx3)
#   Using cached pyobjc_framework_VideoToolbox-11.0-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.4 kB)
# Collecting pyobjc-framework-Virtualization==11.0 (from pyobjc>=2.4->pyttsx3)
#   Using cached pyobjc_framework_Virtualization-11.0-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.3 kB)
# Collecting pyobjc-framework-Vision==11.0 (from pyobjc>=2.4->pyttsx3)
#   Using cached pyobjc_framework_Vision-11.0-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.3 kB)
# Collecting pyobjc-framework-iTunesLibrary==11.0 (from pyobjc>=2.4->pyttsx3)
#   Using cached pyobjc_framework_iTunesLibrary-11.0-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: httplib2<1.0.0,>=0.19.0 in /Users/nitish/opt/anaconda3/envs/llms/lib/python3.11/site-packages (from google-api-python-client->google-generativeai) (0.22.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in /Users/nitish/opt/anaconda3/envs/llms/lib/python3.11/site-packages (from google-api-python-client->google-generativeai) (0.2.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /Users/nitish/opt/anaconda3/envs/llms/lib/python3.11/site-packages (from google-api-python-client->google-generativeai) (4.1.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/nitish/opt/anaconda3/envs/llms/lib/python3.11/site-packages (from pydantic->google-generativeai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /Users/nitish/opt/anaconda3/envs/llms/lib/python3.11/site-packages (from pydantic->google-generativeai) (2.27.2)
# Requirement already satisfied: cffi>=1.12 in /Users/nitish/opt/anaconda3/envs/llms/lib/python3.11/site-packages (from cryptography>=36.0.0->pdfminer.six==20231228->pdfplumber) (1.17.1)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in /Users/nitish/opt/anaconda3/envs/llms/lib/python3.11/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.15->google-generativeai) (1.71.0)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in /Users/nitish/opt/anaconda3/envs/llms/lib/python3.11/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.15->google-generativeai) (1.71.0)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /Users/nitish/opt/anaconda3/envs/llms/lib/python3.11/site-packages (from httplib2<1.0.0,>=0.19.0->google-api-python-client->google-generativeai) (3.2.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /Users/nitish/opt/anaconda3/envs/llms/lib/python3.11/site-packages (from pyasn1-modules>=0.2.1->google-auth>=2.15.0->google-generativeai) (0.6.1)
# Requirement already satisfied: pycparser in /Users/nitish/opt/anaconda3/envs/llms/lib/python3.11/site-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six==20231228->pdfplumber) (2.22)
# Using cached pyttsx3-2.98-py3-none-any.whl (34 kB)
# Using cached pyobjc-11.0-py3-none-any.whl (4.2 kB)
# Using cached pyobjc_framework_Accessibility-11.0-cp311-cp311-macosx_10_9_universal2.whl (10 kB)
# Using cached pyobjc_framework_Accounts-11.0-py3-none-any.whl (5.1 kB)
# Using cached pyobjc_framework_AddressBook-11.0-cp311-cp311-macosx_10_9_universal2.whl (13 kB)
# Using cached pyobjc_framework_AdServices-11.0-py3-none-any.whl (3.5 kB)
# Using cached pyobjc_framework_AdSupport-11.0-py3-none-any.whl (3.4 kB)
# Using cached pyobjc_framework_AppleScriptKit-11.0-py3-none-any.whl (4.3 kB)
# Using cached pyobjc_framework_AppleScriptObjC-11.0-py3-none-any.whl (4.4 kB)
# Using cached pyobjc_framework_ApplicationServices-11.0-cp311-cp311-macosx_10_9_universal2.whl (30 kB)
# Using cached pyobjc_framework_AppTrackingTransparency-11.0-py3-none-any.whl (3.9 kB)
# Using cached pyobjc_framework_AudioVideoBridging-11.0-cp311-cp311-macosx_10_9_universal2.whl (10 kB)
# Using cached pyobjc_framework_AuthenticationServices-11.0-cp311-cp311-macosx_10_9_universal2.whl (20 kB)
# Using cached pyobjc_framework_AutomaticAssessmentConfiguration-11.0-cp311-cp311-macosx_10_9_universal2.whl (9.0 kB)
# Using cached pyobjc_framework_Automator-11.0-cp311-cp311-macosx_10_9_universal2.whl (9.8 kB)
# Using cached pyobjc_framework_AVFoundation-11.0-cp311-cp311-macosx_10_9_universal2.whl (71 kB)
# Using cached pyobjc_framework_AVKit-11.0-cp311-cp311-macosx_10_9_universal2.whl (11 kB)
# Using cached pyobjc_framework_AVRouting-11.0-cp311-cp311-macosx_10_9_universal2.whl (8.1 kB)
# Using cached pyobjc_framework_BackgroundAssets-11.0-cp311-cp311-macosx_10_9_universal2.whl (9.5 kB)
# Using cached pyobjc_framework_BrowserEngineKit-11.0-cp311-cp311-macosx_10_9_universal2.whl (10 kB)
# Using cached pyobjc_framework_BusinessChat-11.0-py3-none-any.whl (3.5 kB)
# Using cached pyobjc_framework_CalendarStore-11.0-py3-none-any.whl (5.3 kB)
# Using cached pyobjc_framework_CallKit-11.0-py3-none-any.whl (5.3 kB)
# Using cached pyobjc_framework_Carbon-11.0-py3-none-any.whl (4.8 kB)
# Using cached pyobjc_framework_CFNetwork-11.0-cp311-cp311-macosx_10_9_universal2.whl (18 kB)
# Using cached pyobjc_framework_Cinematic-11.0-py3-none-any.whl (4.6 kB)
# Using cached pyobjc_framework_ClassKit-11.0-cp311-cp311-macosx_10_9_universal2.whl (8.8 kB)
# Using cached pyobjc_framework_CloudKit-11.0-py3-none-any.whl (10 kB)
# Using cached pyobjc_framework_Collaboration-11.0-py3-none-any.whl (4.9 kB)
# Using cached pyobjc_framework_ColorSync-11.0-py3-none-any.whl (6.0 kB)
# Using cached pyobjc_framework_Contacts-11.0-cp311-cp311-macosx_10_9_universal2.whl (11 kB)
# Using cached pyobjc_framework_ContactsUI-11.0-cp311-cp311-macosx_10_9_universal2.whl (7.7 kB)
# Using cached pyobjc_framework_CoreAudio-11.0-cp311-cp311-macosx_10_9_universal2.whl (35 kB)
# Using cached pyobjc_framework_CoreAudioKit-11.0-cp311-cp311-macosx_10_9_universal2.whl (7.2 kB)
# Using cached pyobjc_framework_CoreBluetooth-11.0-cp311-cp311-macosx_10_9_universal2.whl (13 kB)
# Using cached pyobjc_framework_CoreData-11.0-cp311-cp311-macosx_10_9_universal2.whl (16 kB)
# Using cached pyobjc_framework_CoreHaptics-11.0-py3-none-any.whl (5.4 kB)
# Using cached pyobjc_framework_CoreLocation-11.0-cp311-cp311-macosx_10_9_universal2.whl (13 kB)
# Using cached pyobjc_framework_CoreMedia-11.0-cp311-cp311-macosx_10_9_universal2.whl (29 kB)
# Using cached pyobjc_framework_CoreMediaIO-11.0-cp311-cp311-macosx_10_9_universal2.whl (17 kB)
# Using cached pyobjc_framework_CoreMIDI-11.0-cp311-cp311-macosx_10_9_universal2.whl (24 kB)
# Using cached pyobjc_framework_CoreML-11.0-cp311-cp311-macosx_10_9_universal2.whl (11 kB)
# Using cached pyobjc_framework_CoreMotion-11.0-cp311-cp311-macosx_10_9_universal2.whl (10 kB)
# Using cached pyobjc_framework_CoreServices-11.0-cp311-cp311-macosx_10_9_universal2.whl (30 kB)
# Using cached pyobjc_framework_CoreSpotlight-11.0-cp311-cp311-macosx_10_9_universal2.whl (9.6 kB)
# Using cached pyobjc_framework_CoreText-11.0-cp311-cp311-macosx_10_9_universal2.whl (30 kB)
# Using cached pyobjc_framework_CoreWLAN-11.0-cp311-cp311-macosx_10_9_universal2.whl (9.9 kB)
# Using cached pyobjc_framework_CryptoTokenKit-11.0-cp311-cp311-macosx_10_9_universal2.whl (12 kB)
# Using cached pyobjc_framework_DataDetection-11.0-py3-none-any.whl (3.5 kB)
# Using cached pyobjc_framework_DeviceCheck-11.0-py3-none-any.whl (3.7 kB)
# Using cached pyobjc_framework_DeviceDiscoveryExtension-11.0-py3-none-any.whl (4.3 kB)
# Using cached pyobjc_framework_DictionaryServices-11.0-py3-none-any.whl (3.9 kB)
# Using cached pyobjc_framework_DiscRecording-11.0-cp311-cp311-macosx_10_9_universal2.whl (14 kB)
# Using cached pyobjc_framework_DiscRecordingUI-11.0-py3-none-any.whl (4.7 kB)
# Using cached pyobjc_framework_DiskArbitration-11.0-py3-none-any.whl (4.9 kB)
# Using cached pyobjc_framework_DVDPlayback-11.0-py3-none-any.whl (8.2 kB)
# Using cached pyobjc_framework_EventKit-11.0-py3-none-any.whl (6.8 kB)
# Using cached pyobjc_framework_ExceptionHandling-11.0-py3-none-any.whl (7.1 kB)
# Using cached pyobjc_framework_ExecutionPolicy-11.0-py3-none-any.whl (3.7 kB)
# Using cached pyobjc_framework_ExtensionKit-11.0-cp311-cp311-macosx_10_9_universal2.whl (7.8 kB)
# Using cached pyobjc_framework_ExternalAccessory-11.0-cp311-cp311-macosx_10_9_universal2.whl (8.8 kB)
# Using cached pyobjc_framework_FileProvider-11.0-cp311-cp311-macosx_10_9_universal2.whl (19 kB)
# Using cached pyobjc_framework_FileProviderUI-11.0-py3-none-any.whl (3.7 kB)
# Using cached pyobjc_framework_FinderSync-11.0-py3-none-any.whl (4.9 kB)
# Using cached pyobjc_framework_FSEvents-11.0-cp311-cp311-macosx_10_9_universal2.whl (13 kB)
# Using cached pyobjc_framework_GameCenter-11.0-cp311-cp311-macosx_10_9_universal2.whl (18 kB)
# Using cached pyobjc_framework_GameController-11.0-cp311-cp311-macosx_10_9_universal2.whl (20 kB)
# Using cached pyobjc_framework_GameKit-11.0-cp311-cp311-macosx_10_9_universal2.whl (21 kB)
# Using cached pyobjc_framework_GameplayKit-11.0-cp311-cp311-macosx_10_9_universal2.whl (13 kB)
# Using cached pyobjc_framework_HealthKit-11.0-cp311-cp311-macosx_10_9_universal2.whl (20 kB)
# Using cached pyobjc_framework_ImageCaptureCore-11.0-cp311-cp311-macosx_10_9_universal2.whl (16 kB)
# Using cached pyobjc_framework_InputMethodKit-11.0-cp311-cp311-macosx_10_9_universal2.whl (9.4 kB)
# Using cached pyobjc_framework_InstallerPlugins-11.0-py3-none-any.whl (4.8 kB)
# Using cached pyobjc_framework_InstantMessage-11.0-py3-none-any.whl (5.4 kB)
# Using cached pyobjc_framework_Intents-11.0-cp311-cp311-macosx_10_9_universal2.whl (32 kB)
# Using cached pyobjc_framework_IntentsUI-11.0-cp311-cp311-macosx_10_9_universal2.whl (8.8 kB)
# Using cached pyobjc_framework_IOBluetooth-11.0-cp311-cp311-macosx_10_9_universal2.whl (41 kB)
# Using cached pyobjc_framework_IOBluetoothUI-11.0-py3-none-any.whl (4.0 kB)
# Using cached pyobjc_framework_IOSurface-11.0-py3-none-any.whl (5.0 kB)
# Using cached pyobjc_framework_iTunesLibrary-11.0-py3-none-any.whl (5.2 kB)
# Using cached pyobjc_framework_KernelManagement-11.0-py3-none-any.whl (3.7 kB)
# Using cached pyobjc_framework_LatentSemanticMapping-11.0-py3-none-any.whl (5.4 kB)
# Using cached pyobjc_framework_LaunchServices-11.0-py3-none-any.whl (3.9 kB)
# Using cached pyobjc_framework_libdispatch-11.0-cp311-cp311-macosx_10_9_universal2.whl (20 kB)
# Using cached pyobjc_framework_libxpc-11.0-cp311-cp311-macosx_10_9_universal2.whl (19 kB)
# Using cached pyobjc_framework_LinkPresentation-11.0-py3-none-any.whl (3.9 kB)
# Using cached pyobjc_framework_LocalAuthentication-11.0-cp311-cp311-macosx_10_9_universal2.whl (10 kB)
# Using cached pyobjc_framework_LocalAuthenticationEmbeddedUI-11.0-py3-none-any.whl (4.0 kB)
# Using cached pyobjc_framework_MailKit-11.0-py3-none-any.whl (4.9 kB)
# Using cached pyobjc_framework_MapKit-11.0-cp311-cp311-macosx_10_9_universal2.whl (23 kB)
# Using cached pyobjc_framework_MediaAccessibility-11.0-py3-none-any.whl (4.7 kB)
# Using cached pyobjc_framework_MediaExtension-11.0-cp311-cp311-macosx_10_9_universal2.whl (39 kB)
# Using cached pyobjc_framework_MediaLibrary-11.0-py3-none-any.whl (4.4 kB)
# Using cached pyobjc_framework_MediaPlayer-11.0-py3-none-any.whl (7.0 kB)
# Using cached pyobjc_framework_MediaToolbox-11.0-cp311-cp311-macosx_10_9_universal2.whl (12 kB)
# Using cached pyobjc_framework_Metal-11.0-cp311-cp311-macosx_10_9_universal2.whl (57 kB)
# Using cached pyobjc_framework_MetalFX-11.0-cp311-cp311-macosx_10_9_universal2.whl (10 kB)
# Using cached pyobjc_framework_MetalKit-11.0-cp311-cp311-macosx_10_9_universal2.whl (8.6 kB)
# Using cached pyobjc_framework_MetalPerformanceShaders-11.0-cp311-cp311-macosx_10_9_universal2.whl (33 kB)
# Using cached pyobjc_framework_MetalPerformanceShadersGraph-11.0-py3-none-any.whl (6.5 kB)
# Using cached pyobjc_framework_MetricKit-11.0-cp311-cp311-macosx_10_9_universal2.whl (8.0 kB)
# Using cached pyobjc_framework_MLCompute-11.0-py3-none-any.whl (6.8 kB)
# Using cached pyobjc_framework_ModelIO-11.0-cp311-cp311-macosx_10_9_universal2.whl (20 kB)
# Using cached pyobjc_framework_MultipeerConnectivity-11.0-cp311-cp311-macosx_10_9_universal2.whl (12 kB)
# Using cached pyobjc_framework_NaturalLanguage-11.0-py3-none-any.whl (5.3 kB)
# Using cached pyobjc_framework_NetFS-11.0-py3-none-any.whl (4.2 kB)
# Using cached pyobjc_framework_Network-11.0-cp311-cp311-macosx_10_9_universal2.whl (19 kB)
# Using cached pyobjc_framework_NetworkExtension-11.0-cp311-cp311-macosx_10_9_universal2.whl (13 kB)
# Using cached pyobjc_framework_NotificationCenter-11.0-cp311-cp311-macosx_10_9_universal2.whl (9.7 kB)
# Using cached pyobjc_framework_OpenDirectory-11.0-py3-none-any.whl (11 kB)
# Using cached pyobjc_framework_OSAKit-11.0-py3-none-any.whl (4.2 kB)
# Using cached pyobjc_framework_OSLog-11.0-cp311-cp311-macosx_10_9_universal2.whl (7.7 kB)
# Using cached pyobjc_framework_PassKit-11.0-cp311-cp311-macosx_10_9_universal2.whl (14 kB)
# Using cached pyobjc_framework_PencilKit-11.0-py3-none-any.whl (4.0 kB)
# Using cached pyobjc_framework_PHASE-11.0-py3-none-any.whl (6.8 kB)
# Using cached pyobjc_framework_Photos-11.0-cp311-cp311-macosx_10_9_universal2.whl (12 kB)
# Using cached pyobjc_framework_PhotosUI-11.0-cp311-cp311-macosx_10_9_universal2.whl (12 kB)
# Using cached pyobjc_framework_PreferencePanes-11.0-py3-none-any.whl (4.8 kB)
# Using cached pyobjc_framework_PushKit-11.0-cp311-cp311-macosx_10_9_universal2.whl (8.0 kB)
# Using cached pyobjc_framework_Quartz-11.0-cp311-cp311-macosx_10_9_universal2.whl (212 kB)
# Using cached pyobjc_framework_QuickLookThumbnailing-11.0-py3-none-any.whl (4.2 kB)
# Using cached pyobjc_framework_ReplayKit-11.0-cp311-cp311-macosx_10_9_universal2.whl (9.9 kB)
# Using cached pyobjc_framework_SafariServices-11.0-cp311-cp311-macosx_10_9_universal2.whl (7.3 kB)
# Using cached pyobjc_framework_SafetyKit-11.0-cp311-cp311-macosx_10_9_universal2.whl (8.4 kB)
# Using cached pyobjc_framework_SceneKit-11.0-cp311-cp311-macosx_10_9_universal2.whl (33 kB)
# Using cached pyobjc_framework_ScreenCaptureKit-11.0-cp311-cp311-macosx_10_9_universal2.whl (11 kB)
# Using cached pyobjc_framework_ScreenSaver-11.0-cp311-cp311-macosx_10_9_universal2.whl (8.4 kB)
# Using cached pyobjc_framework_ScreenTime-11.0-py3-none-any.whl (3.8 kB)
# Using cached pyobjc_framework_ScriptingBridge-11.0-cp311-cp311-macosx_10_9_universal2.whl (8.2 kB)
# Using cached pyobjc_framework_SearchKit-11.0-py3-none-any.whl (3.7 kB)
# Using cached pyobjc_framework_Security-11.0-cp311-cp311-macosx_10_9_universal2.whl (41 kB)
# Using cached pyobjc_framework_SecurityFoundation-11.0-py3-none-any.whl (3.8 kB)
# Using cached pyobjc_framework_SecurityInterface-11.0-cp311-cp311-macosx_10_9_universal2.whl (10 kB)
# Using cached pyobjc_framework_SensitiveContentAnalysis-11.0-py3-none-any.whl (3.9 kB)
# Using cached pyobjc_framework_ServiceManagement-11.0-py3-none-any.whl (5.3 kB)
# Using cached pyobjc_framework_SharedWithYou-11.0-cp311-cp311-macosx_10_9_universal2.whl (8.6 kB)
# Using cached pyobjc_framework_SharedWithYouCore-11.0-cp311-cp311-macosx_10_9_universal2.whl (8.4 kB)
# Using cached pyobjc_framework_ShazamKit-11.0-cp311-cp311-macosx_10_9_universal2.whl (8.4 kB)
# Using cached pyobjc_framework_Social-11.0-py3-none-any.whl (4.4 kB)
# Using cached pyobjc_framework_SoundAnalysis-11.0-py3-none-any.whl (4.2 kB)
# Using cached pyobjc_framework_Speech-11.0-cp311-cp311-macosx_10_9_universal2.whl (9.0 kB)
# Using cached pyobjc_framework_SpriteKit-11.0-cp311-cp311-macosx_10_9_universal2.whl (18 kB)
# Using cached pyobjc_framework_StoreKit-11.0-cp311-cp311-macosx_10_9_universal2.whl (11 kB)
# Using cached pyobjc_framework_Symbols-11.0-py3-none-any.whl (3.3 kB)
# Using cached pyobjc_framework_SyncServices-11.0-cp311-cp311-macosx_10_9_universal2.whl (13 kB)
# Using cached pyobjc_framework_SystemConfiguration-11.0-cp311-cp311-macosx_10_9_universal2.whl (21 kB)
# Using cached pyobjc_framework_SystemExtensions-11.0-cp311-cp311-macosx_10_9_universal2.whl (9.0 kB)
# Using cached pyobjc_framework_ThreadNetwork-11.0-py3-none-any.whl (3.8 kB)
# Using cached pyobjc_framework_UniformTypeIdentifiers-11.0-py3-none-any.whl (4.9 kB)
# Using cached pyobjc_framework_UserNotifications-11.0-cp311-cp311-macosx_10_9_universal2.whl (9.5 kB)
# Using cached pyobjc_framework_UserNotificationsUI-11.0-py3-none-any.whl (3.9 kB)
# Using cached pyobjc_framework_VideoSubscriberAccount-11.0-py3-none-any.whl (4.7 kB)
# Using cached pyobjc_framework_VideoToolbox-11.0-cp311-cp311-macosx_10_9_universal2.whl (13 kB)
# Using cached pyobjc_framework_Virtualization-11.0-cp311-cp311-macosx_10_9_universal2.whl (13 kB)
# Using cached pyobjc_framework_Vision-11.0-cp311-cp311-macosx_10_9_universal2.whl (21 kB)
# Using cached pyobjc_framework_WebKit-11.0-cp311-cp311-macosx_10_9_universal2.whl (44 kB)
# Installing collected packages: pyobjc-framework-WebKit, pyobjc-framework-Virtualization, pyobjc-framework-VideoSubscriberAccount, pyobjc-framework-UserNotifications, pyobjc-framework-UniformTypeIdentifiers, pyobjc-framework-ThreadNetwork, pyobjc-framework-SystemExtensions, pyobjc-framework-SystemConfiguration, pyobjc-framework-Symbols, pyobjc-framework-StoreKit, pyobjc-framework-Speech, pyobjc-framework-SoundAnalysis, pyobjc-framework-Social, pyobjc-framework-ShazamKit, pyobjc-framework-SharedWithYouCore, pyobjc-framework-ServiceManagement, pyobjc-framework-Security, pyobjc-framework-ScriptingBridge, pyobjc-framework-ScreenTime, pyobjc-framework-ScreenSaver, pyobjc-framework-SafariServices, pyobjc-framework-ReplayKit, pyobjc-framework-Quartz, pyobjc-framework-PushKit, pyobjc-framework-PreferencePanes, pyobjc-framework-PhotosUI, pyobjc-framework-Photos, pyobjc-framework-PencilKit, pyobjc-framework-PassKit, pyobjc-framework-OSAKit, pyobjc-framework-OpenDirectory, pyobjc-framework-NotificationCenter, pyobjc-framework-NetworkExtension, pyobjc-framework-Network, pyobjc-framework-NetFS, pyobjc-framework-NaturalLanguage, pyobjc-framework-MultipeerConnectivity, pyobjc-framework-MLCompute, pyobjc-framework-MetricKit, pyobjc-framework-Metal, pyobjc-framework-MediaToolbox, pyobjc-framework-MediaAccessibility, pyobjc-framework-MailKit, pyobjc-framework-libxpc, pyobjc-framework-libdispatch, pyobjc-framework-LatentSemanticMapping, pyobjc-framework-KernelManagement, pyobjc-framework-iTunesLibrary, pyobjc-framework-IOSurface, pyobjc-framework-IOBluetooth, pyobjc-framework-Intents, pyobjc-framework-InstallerPlugins, pyobjc-framework-InputMethodKit, pyobjc-framework-ImageCaptureCore, pyobjc-framework-HealthKit, pyobjc-framework-GameController, pyobjc-framework-GameCenter, pyobjc-framework-FSEvents, pyobjc-framework-FinderSync, pyobjc-framework-FileProvider, pyobjc-framework-ExternalAccessory, pyobjc-framework-ExtensionKit, pyobjc-framework-ExecutionPolicy, pyobjc-framework-ExceptionHandling, pyobjc-framework-EventKit, pyobjc-framework-DVDPlayback, pyobjc-framework-DiskArbitration, pyobjc-framework-DiscRecording, pyobjc-framework-DeviceDiscoveryExtension, pyobjc-framework-DeviceCheck, pyobjc-framework-DataDetection, pyobjc-framework-CryptoTokenKit, pyobjc-framework-CoreWLAN, pyobjc-framework-CoreSpotlight, pyobjc-framework-CoreMotion, pyobjc-framework-CoreML, pyobjc-framework-CoreMIDI, pyobjc-framework-CoreMediaIO, pyobjc-framework-CoreMedia, pyobjc-framework-CoreLocation, pyobjc-framework-CoreHaptics, pyobjc-framework-CoreData, pyobjc-framework-CoreBluetooth, pyobjc-framework-CoreAudio, pyobjc-framework-Contacts, pyobjc-framework-ColorSync, pyobjc-framework-Collaboration, pyobjc-framework-ClassKit, pyobjc-framework-CFNetwork, pyobjc-framework-Carbon, pyobjc-framework-CallKit, pyobjc-framework-CalendarStore, pyobjc-framework-BusinessChat, pyobjc-framework-BackgroundAssets, pyobjc-framework-AVRouting, pyobjc-framework-Automator, pyobjc-framework-AutomaticAssessmentConfiguration, pyobjc-framework-AuthenticationServices, pyobjc-framework-AudioVideoBridging, pyobjc-framework-AppTrackingTransparency, pyobjc-framework-AppleScriptObjC, pyobjc-framework-AppleScriptKit, pyobjc-framework-AdSupport, pyobjc-framework-AdServices, pyobjc-framework-AddressBook, pyobjc-framework-Accounts, pyobjc-framework-Vision, pyobjc-framework-VideoToolbox, pyobjc-framework-UserNotificationsUI, pyobjc-framework-SyncServices, pyobjc-framework-SpriteKit, pyobjc-framework-SharedWithYou, pyobjc-framework-SensitiveContentAnalysis, pyobjc-framework-SecurityInterface, pyobjc-framework-SecurityFoundation, pyobjc-framework-ScreenCaptureKit, pyobjc-framework-SceneKit, pyobjc-framework-SafetyKit, pyobjc-framework-QuickLookThumbnailing, pyobjc-framework-OSLog, pyobjc-framework-ModelIO, pyobjc-framework-MetalPerformanceShaders, pyobjc-framework-MetalKit, pyobjc-framework-MetalFX, pyobjc-framework-MediaLibrary, pyobjc-framework-MapKit, pyobjc-framework-LocalAuthentication, pyobjc-framewor ...
# Successfully installed pyobjc-11.0 pyobjc-framework-AVFoundation-11.0 pyobjc-framework-AVKit-11.0 pyobjc-framework-AVRouting-11.0 pyobjc-framework-Accessibility-11.0 pyobjc-framework-Accounts-11.0 pyobjc-framework-AdServices-11.0 pyobjc-framework-AdSupport-11.0 pyobjc-framework-AddressBook-11.0 pyobjc-framework-AppTrackingTransparency-11.0 pyobjc-framework-AppleScriptKit-11.0 pyobjc-framework-AppleScriptObjC-11.0 pyobjc-framework-ApplicationServices-11.0 pyobjc-framework-AudioVideoBridging-11.0 pyobjc-framework-AuthenticationServices-11.0 pyobjc-framework-AutomaticAssessmentConfiguration-11.0 pyobjc-framework-Automator-11.0 pyobjc-framework-BackgroundAssets-11.0 pyobjc-framework-BrowserEngineKit-11.0 pyobjc-framework-BusinessChat-11.0 pyobjc-framework-CFNetwork-11.0 pyobjc-framework-CalendarStore-11.0 pyobjc-framework-CallKit-11.0 pyobjc-framework-Carbon-11.0 pyobjc-framework-Cinematic-11.0 pyobjc-framework-ClassKit-11.0 pyobjc-framework-CloudKit-11.0 pyobjc-framework-Collaboration-11.0 pyobjc-framework-ColorSync-11.0 pyobjc-framework-Contacts-11.0 pyobjc-framework-ContactsUI-11.0 pyobjc-framework-CoreAudio-11.0 pyobjc-framework-CoreAudioKit-11.0 pyobjc-framework-CoreBluetooth-11.0 pyobjc-framework-CoreData-11.0 pyobjc-framework-CoreHaptics-11.0 pyobjc-framework-CoreLocation-11.0 pyobjc-framework-CoreMIDI-11.0 pyobjc-framework-CoreML-11.0 pyobjc-framework-CoreMedia-11.0 pyobjc-framework-CoreMediaIO-11.0 pyobjc-framework-CoreMotion-11.0 pyobjc-framework-CoreServices-11.0 pyobjc-framework-CoreSpotlight-11.0 pyobjc-framework-CoreText-11.0 pyobjc-framework-CoreWLAN-11.0 pyobjc-framework-CryptoTokenKit-11.0 pyobjc-framework-DVDPlayback-11.0 pyobjc-framework-DataDetection-11.0 pyobjc-framework-DeviceCheck-11.0 pyobjc-framework-DeviceDiscoveryExtension-11.0 pyobjc-framework-DictionaryServices-11.0 pyobjc-framework-DiscRecording-11.0 pyobjc-framework-DiscRecordingUI-11.0 pyobjc-framework-DiskArbitration-11.0 pyobjc-framework-EventKit-11.0 pyobjc-framework-ExceptionHandling-11.0 pyobjc-framework-ExecutionPolicy-11.0 pyobjc-framework-ExtensionKit-11.0 pyobjc-framework-ExternalAccessory-11.0 pyobjc-framework-FSEvents-11.0 pyobjc-framework-FileProvider-11.0 pyobjc-framework-FileProviderUI-11.0 pyobjc-framework-FinderSync-11.0 pyobjc-framework-GameCenter-11.0 pyobjc-framework-GameController-11.0 pyobjc-framework-GameKit-11.0 pyobjc-framework-GameplayKit-11.0 pyobjc-framework-HealthKit-11.0 pyobjc-framework-IOBluetooth-11.0 pyobjc-framework-IOBluetoothUI-11.0 pyobjc-framework-IOSurface-11.0 pyobjc-framework-ImageCaptureCore-11.0 pyobjc-framework-InputMethodKit-11.0 pyobjc-framework-InstallerPlugins-11.0 pyobjc-framework-InstantMessage-11.0 pyobjc-framework-Intents-11.0 pyobjc-framework-IntentsUI-11.0 pyobjc-framework-KernelManagement-11.0 pyobjc-framework-LatentSemanticMapping-11.0 pyobjc-framework-LaunchServices-11.0 pyobjc-framework-LinkPresentation-11.0 pyobjc-framework-LocalAuthentication-11.0 pyobjc-framework-LocalAuthenticationEmbeddedUI-11.0 pyobjc-framework-MLCompute-11.0 pyobjc-framework-MailKit-11.0 pyobjc-framework-MapKit-11.0 pyobjc-framework-MediaAccessibility-11.0 pyobjc-framework-MediaExtension-11.0 pyobjc-framework-MediaLibrary-11.0 pyobjc-framework-MediaPlayer-11.0 pyobjc-framework-MediaToolbox-11.0 pyobjc-framework-Metal-11.0 pyobjc-framework-MetalFX-11.0 pyobjc-framework-MetalKit-11.0 pyobjc-framework-MetalPerformanceShaders-11.0 pyobjc-framework-MetalPerformanceShadersGraph-11.0 pyobjc-framework-MetricKit-11.0 pyobjc-framework-ModelIO-11.0 pyobjc-framework-MultipeerConnectivity-11.0 pyobjc-framework-NaturalLanguage-11.0 pyobjc-framework-NetFS-11.0 pyobjc-framework-Network-11.0 pyobjc-framework-NetworkExtension-11.0 pyobjc-framework-NotificationCenter-11.0 pyobjc-framework-OSAKit-11.0 pyobjc-framework-OSLog-11.0 pyobjc-framework-OpenDirectory-11.0 pyobjc-framework-PHASE-11.0 pyobjc-framework-PassKit-11.0 pyobjc-framework-PencilKit-11.0 pyobjc-framework-Photos-11.0 pyobjc-framework-PhotosUI-11.0 pyobjc-framework-Preference ...

# %%
# !pip install pipwin
# !pipwin install pyaudio
# Out:
# Collecting pipwin
#   Downloading pipwin-0.5.2.tar.gz (7.9 kB)
#   Preparing metadata (setup.py) ... done
# Collecting docopt (from pipwin)
#   Downloading docopt-0.6.2.tar.gz (25 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: requests in /Users/nitish/opt/anaconda3/envs/llms/lib/python3.11/site-packages (from pipwin) (2.32.3)
# Collecting pyprind (from pipwin)
#   Downloading PyPrind-2.11.3-py2.py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: six in /Users/nitish/opt/anaconda3/envs/llms/lib/python3.11/site-packages (from pipwin) (1.17.0)
# Requirement already satisfied: beautifulsoup4>=4.9.0 in /Users/nitish/opt/anaconda3/envs/llms/lib/python3.11/site-packages (from pipwin) (4.13.3)
# Collecting js2py (from pipwin)
#   Downloading Js2Py-0.74-py3-none-any.whl.metadata (868 bytes)
# Requirement already satisfied: packaging in /Users/nitish/opt/anaconda3/envs/llms/lib/python3.11/site-packages (from pipwin) (24.2)
# Collecting pySmartDL>=1.3.1 (from pipwin)
#   Downloading pySmartDL-1.3.4-py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: soupsieve>1.2 in /Users/nitish/opt/anaconda3/envs/llms/lib/python3.11/site-packages (from beautifulsoup4>=4.9.0->pipwin) (2.5)
# Requirement already satisfied: typing-extensions>=4.0.0 in /Users/nitish/opt/anaconda3/envs/llms/lib/python3.11/site-packages (from beautifulsoup4>=4.9.0->pipwin) (4.12.2)
# Collecting tzlocal>=1.2 (from js2py->pipwin)
#   Downloading tzlocal-5.3.1-py3-none-any.whl.metadata (7.6 kB)
# Collecting pyjsparser>=2.5.1 (from js2py->pipwin)
#   Downloading pyjsparser-2.7.1.tar.gz (24 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/nitish/opt/anaconda3/envs/llms/lib/python3.11/site-packages (from requests->pipwin) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /Users/nitish/opt/anaconda3/envs/llms/lib/python3.11/site-packages (from requests->pipwin) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/nitish/opt/anaconda3/envs/llms/lib/python3.11/site-packages (from requests->pipwin) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/nitish/opt/anaconda3/envs/llms/lib/python3.11/site-packages (from requests->pipwin) (2025.1.31)
# Downloading pySmartDL-1.3.4-py3-none-any.whl (20 kB)
# Downloading Js2Py-0.74-py3-none-any.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 12.5 MB/s eta 0:00:00
# Downloading PyPrind-2.11.3-py2.py3-none-any.whl (8.4 kB)
# Downloading tzlocal-5.3.1-py3-none-any.whl (18 kB)
# Building wheels for collected packages: pipwin, docopt, pyjsparser
#   Building wheel for pipwin (setup.py) ... done
#   Created wheel for pipwin: filename=pipwin-0.5.2-py2.py3-none-any.whl size=8848 sha256=93e4634070485fdd123ba5fcfc18f88d732fcb556543247c6d9fe1c38a523385
#   Stored in directory: /Users/nitish/Library/Caches/pip/wheels/07/45/2e/51ee464b7c3407327439df34c2fc62f978a1e5084aaf23d201
#   Building wheel for docopt (setup.py) ... done
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13782 sha256=f5ab208c1a6edce483ee469ebc13a0d8ee4c805f4cd3f796b58e3d82c411dc7c
#   Stored in directory: /Users/nitish/Library/Caches/pip/wheels/1a/b0/8c/4b75c4116c31f83c8f9f047231251e13cc74481cca4a78a9ce
#   Building wheel for pyjsparser (setup.py) ... done
#   Created wheel for pyjsparser: filename=pyjsparser-2.7.1-py3-none-any.whl size=26011 sha256=8046e5b326811a098516f4abd362dfa601549fec7dfc7684e229f25934303806
#   Stored in directory: /Users/nitish/Library/Caches/pip/wheels/a5/9a/30/1003e89ab4555b81840ca46d361bf184f1e6ad880cae3b62a9
# Successfully built pipwin docopt pyjsparser
# Installing collected packages: pySmartDL, pyprind, pyjsparser, docopt, tzlocal, js2py, pipwin
# Successfully installed docopt-0.6.2 js2py-0.74 pipwin-0.5.2 pySmartDL-1.3.4 pyjsparser-2.7.1 pyprind-2.11.3 tzlocal-5.3.1
# /Users/nitish/opt/anaconda3/envs/llms/lib/python3.11/site-packages/pipwin/command.py:66: UserWarning: Found a non Windows system. Package installation might not work.
#   warn("Found a non Windows system. Package installation might not work.")
# Building cache. Hang on . . .
# Traceback (most recent call last):
#   File "/Users/nitish/opt/anaconda3/envs/llms/bin/pipwin", line 8, in <module>
#     sys.exit(main())
#              ^^^^^^
#   File "/Users/nitish/opt/anaconda3/envs/llms/lib/python3.11/site-packages/pipwin/command.py", line 84, in main
#     cache = pipwin.PipwinCache()
#             ^^^^^^^^^^^^^^^^^^^^
#   File "/Users/nitish/opt/anaconda3/envs/llms/lib/python3.11/site-packages/pipwin/pipwin.py", line 210, in __init__
#     self.data = build_cache()
#                 ^^^^^^^^^^^^^
#   File "/Users/nitish/opt/anaconda3/envs/llms/lib/python3.11/site-packages/pipwin/pipwin.py", line 103, in build_cache
#     dl_function = re.search(r"function dl.*\}", soup.find("script").string).group(0)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: 'NoneType' object has no attribute 'group'

# %%
# !pip install SpeechRecognition
# Out:
# Collecting SpeechRecognition
#   Using cached speechrecognition-3.14.2-py3-none-any.whl.metadata (30 kB)
# Requirement already satisfied: typing-extensions in /Users/nitish/opt/anaconda3/envs/llms/lib/python3.11/site-packages (from SpeechRecognition) (4.12.2)
# Using cached speechrecognition-3.14.2-py3-none-any.whl (32.9 MB)
# Installing collected packages: SpeechRecognition
# Successfully installed SpeechRecognition-3.14.2

# %%
import speech_recognition as sr
import pyttsx3
import pdfplumber
import docx
import os
import logging
from google.generativeai import GenerativeModel, configure
from IPython.display import display
import ipywidgets as widgets

# Set up logging
logging.basicConfig(filename="interview_errors.log", level=logging.ERROR)

# Configure Gemini API
GEMINI_API_KEY = "AIzaSyDS0SXbtLKaawt2IdjTezO8HzsaSoM6RJM"  # Replace with your actual key
configure(api_key=GEMINI_API_KEY)
gemini_model = GenerativeModel("gemini-1.5-flash")

# ----------- RESUME PARSER ------------
def extract_resume_text(file_path):
    if file_path.endswith(".pdf"):
        with pdfplumber.open(file_path) as pdf:
            return "\n".join([page.extract_text() for page in pdf.pages if page.extract_text()])
    elif file_path.endswith(".docx"):
        doc = docx.Document(file_path)
        return "\n".join([para.text for para in doc.paragraphs])
    else:
        raise ValueError("Unsupported file format. Upload a PDF or DOCX.")

# ----------- QUESTIONNAIRE CLASS ------------
class Questionnaire:
    def __init__(self):
        self.questions = []
        self.responses = []

    def generate_initial_question(self, resume_info):
        prompt = f"Generate an interview question based on this resume: {resume_info}"
        try:
            response = gemini_model.generate_content(prompt)
            self.questions = [{"question": response.text.strip()}]
        except Exception as e:
            logging.error(f"Error generating initial question: {e}")
            self.questions = []

    def generate_next_question(self, resume_info, prev_answer):
        prompt = f"""
        Based on this resume and the previous answer, generate a relevant follow-up question.

        Resume: {resume_info}
        Previous Answer: {prev_answer}
        """
        try:
            response = gemini_model.generate_content(prompt)
            self.questions = [{"question": response.text.strip()}]
        except Exception as e:
            logging.error(f"Error generating follow-up question: {e}")
            self.questions = []

    def get_next_question(self):
        return self.questions.pop(0) if self.questions else None

# ----------- INTERVIEW CLASS ------------
class AIInterview:
    def __init__(self, resume_text):
        self.resume_text = resume_text
        self.recognizer = sr.Recognizer()
        self.tts = pyttsx3.init()
        self.questionnaire = Questionnaire()
        self.responses = []

        self.tts.setProperty("rate", 150)
        for voice in self.tts.getProperty("voices"):
            if "Indian" in voice.name:
                self.tts.setProperty("voice", voice.id)
                break

    def speak(self, text):
        print(f"AI: {text}")
        self.tts.say(text)
        self.tts.runAndWait()

    def listen(self, timeout=10, phrase_time_limit=300):
        with sr.Microphone() as source:
            print("Listening (up to 5 mins)...")
            self.recognizer.adjust_for_ambient_noise(source, duration=1)
            try:
                audio = self.recognizer.listen(source, timeout=timeout, phrase_time_limit=phrase_time_limit)
                text = self.recognizer.recognize_google(audio)
                print(f"You: {text}")
                return text
            except sr.UnknownValueError:
                return "Sorry, I couldn't understand you."
            except sr.WaitTimeoutError:
                return "No response detected."
            except sr.RequestError as e:
                return f"Speech recognition error: {e}"

    def give_feedback(self):
        all_responses = "\n".join([f"Q: {r['question']}\nA: {r['answer']}" for r in self.responses])
        prompt = f"""
        Here are the candidate's interview answers. Please provide constructive feedback and a score out of 10.

        {all_responses}
        """
        try:
            feedback = gemini_model.generate_content(prompt)
            self.speak("Here is your final feedback.")
            print("📋 Final Feedback:")
            print(feedback.text.strip())
            self.speak(feedback.text.strip())
        except Exception as e:
            self.speak("Sorry, I couldn't generate feedback at this moment.")
            logging.error(f"Feedback generation error: {e}")

    def conduct(self, num_questions=5):
        self.speak("Welcome to the AI interview. Let's begin.")

        # Initial question
        self.questionnaire.generate_initial_question(self.resume_text)

        for _ in range(num_questions):
            question = self.questionnaire.get_next_question()
            if not question:
                break

            self.speak(question["question"])
            answer = self.listen()

            self.responses.append({"question": question["question"], "answer": answer})

            self.questionnaire.generate_next_question(self.resume_text, answer)

        self.give_feedback()

# ----------- UPLOAD WIDGET FOR RESUME ------------
upload_widget = widgets.FileUpload(accept='.pdf,.docx', multiple=False)
display(upload_widget)

def on_upload_resume(change):
    for filename, fileinfo in upload_widget.value.items():
        file_path = f"./{filename}"
        with open(file_path, "wb") as f:
            f.write(fileinfo['content'])

        try:
            resume_text = extract_resume_text(file_path)
            print("✅ Resume uploaded and parsed successfully.")
            interview = AIInterview(resume_text=resume_text)
            interview.conduct(num_questions=3)  # Set to 3 for demo; you can increase to 5
        except Exception as e:
            print(f"❌ Error parsing resume: {e}")

upload_widget.observe(on_upload_resume, names='value')
# Out:
# FileUpload(value=(), accept='.pdf,.docx', description='Upload')
