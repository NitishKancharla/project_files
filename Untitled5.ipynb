# %%
# !pip install langgraph smolagents llama-index openai streamlit

# %%
from smolagents import tools
print(dir(tools))
# Out:
# ['AUTHORIZED_TYPES', 'BASE_BUILTIN_MODULES', 'CONVERSION_DICT', 'Callable', 'CommitOperationAdd', 'Dict', 'List', 'MethodChecker', 'Optional', 'Path', 'PipelineTool', 'TYPE_CHECKING', 'Tool', 'ToolCollection', 'TypeHintParsingException', 'Union', '__all__', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', '_convert_type_hints_to_json_schema', '_is_package_available', 'add_description', 'ast', 'contextmanager', 'create_commit', 'create_repo', 'get_collection', 'get_imports', 'get_json_schema', 'get_source', 'get_tools_definition_code', 'handle_agent_input_types', 'handle_agent_output_types', 'hf_hub_download', 'inspect', 'instance_to_source', 'is_valid_name', 'json', 'launch_gradio_demo', 'load_tool', 'logger', 'logging', 'metadata_update', 'os', 'sys', 'tempfile', 'textwrap', 'tool', 'types', 'validate_after_init', 'validate_tool_attributes', 'wraps']

# %%
pip install --upgrade smolagents
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
